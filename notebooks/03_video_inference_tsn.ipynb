# %%
import os.path as osp
from operator import itemgetter
from typing import Optional, Tuple
import tempfile
from collections import deque
import os
import cv2

from mmengine import Config
from mmaction.apis import inference_recognizer, init_recognizer
from mmaction.visualization import ActionVisualizer

# 参数直接在Notebook中定义
config = '../configs/recognition/tsn/tsn_imagenet-pretrained-r50_8xb32-1x1x3-100e_xiandemo-rgb.py'  # 配置文件路径
checkpoint = '../work_dirs/xiandemo_tsn/epoch_100.pth'  # 检查点文件
video = '../data/xian_video_dataset/pre/VID_20240905_104444.mp4'  # 视频文件或帧文件路径
# video = '../data/xian_video_dataset/val/1 (1).mp4'  # 视频文件或帧文件路径
label_file = '../data/xian_video_dataset/label_map.txt'  # 标签文件路径
out_filename = '../data/xian_video_dataset/output_tsn_video.mp4'  # 输出文件路径
fps = 30  # 输出视频的FPS
font_scale = None  # 字体大小
font_color = 'white'  # 字体颜色
target_resolution = (256, 256)  # 目标分辨率（宽，高）
device = 'cuda:0'  # 使用的设备

clip_length = 15  # 每次推理使用的帧数
interval = 1  # 帧间隔
# 从配置文件中加载模型配置
cfg = Config.fromfile(config)

print(f"-------- cfg: {cfg.test_pipeline[1]}")

cfg.test_pipeline[1].num_clips=2
cfg.test_pipeline[1].clip_len=3

print(f"--------- cfg: {cfg.test_pipeline[1]}")

model = init_recognizer(cfg, checkpoint, device=device)

# 获取标签
labels = [x.strip() for x in open(label_file).readlines()]

print(f"labels: {labels}")

# 视频读取
from collections import deque


cap = cv2.VideoCapture(video)
num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"num_frames: {num_frames}")
frame_queue = deque(maxlen=clip_length)

results = []
temp_videos = []  # 存储临时短视频片段路径
for i in range(num_frames):
    ret, frame = cap.read()
    if not ret:
        break

    # 缓存帧用于分段推理
    results = []
    frame_queue.append(frame)
    if len(frame_queue) == clip_length:
        # 临时保存帧队列为视频文件
        temp_dir = '/root/project/research/action/mmaction2/demo_out/temp'
        with tempfile.NamedTemporaryFile(delete=False, suffix=".mp4", dir=temp_dir) as temp_video:
            temp_video_path = os.path.join('./' , temp_video.name)
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            print(f"temp_video_path: {temp_video_path}, temp_video.name: {temp_video.name}")
            video_writer = cv2.VideoWriter(temp_video_path, fourcc, fps, (frame.shape[1], frame.shape[0]))

            for buffered_frame in frame_queue:
                video_writer.write(buffered_frame)
            video_writer.release()
            
        # 推理并保存结果
        pred_result = inference_recognizer(model, temp_video_path)
        pred_scores = pred_result.pred_score.tolist()
        score_sorted = sorted(enumerate(pred_scores), key=itemgetter(1), reverse=True)
        top5_label = score_sorted[:5]
        print(f"top5_label: {top5_label}")
        top_label = labels[score_sorted[0][0]]
        results.append((i, top_label))
        print(f"results: {results}")

        # 重新打开临时视频文件以添加推理结果
        video_writer = cv2.VideoWriter(temp_video_path, fourcc, fps, (frame.shape[1], frame.shape[0]))
        for buffered_frame in frame_queue:
            # 在每一帧中写入识别的动作类别
            cv2.putText(buffered_frame, f"Action: {top_label}", (10, 30), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
            video_writer.write(buffered_frame)
        video_writer.release()
        
        temp_videos.append(temp_video_path)  # 添加至临时视频列表
        # 清空缓冲队列，开始新的片段
        frame_queue.clear()  

cap.release()
# Out:
# -------- cfg: {'type': 'SampleFrames', 'clip_len': 1, 'frame_interval': 1, 'num_clips': 25, 'test_mode': True}
# --------- cfg: {'type': 'SampleFrames', 'clip_len': 3, 'frame_interval': 1, 'num_clips': 2, 'test_mode': True}
# Loads checkpoint by local backend from path: ../work_dirs/xiandemo_tsn/epoch_100.pth
# labels: ['en', 'na', 'si', 'tie', 'zhuan']
# num_frames: 551
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tm
]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmprukxcm4t.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmprukxcm4t.mp4
# top5_label: [(0, 0.31712576746940613), (2, 0.2823028862476349), (1, 0.20046594738960266), (3, 0.1904095560312271), (4, 0.00969579815864563)]
# results: [(209, 'en')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmphx0hszeo.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmphx0hszeo.mp4
# top5_label: [(1, 0.9993703961372375), (2, 0.0003306385478936136), (3, 0.0002404756232863292), (0, 4.9927813961403444e-05), (4, 8.480392352794297e-06)]
# results: [(224, 'na')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp4wzt73mr.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp4wzt73mr.mp4
# top5_label: [(1, 0.9999997615814209), (3, 1.1834220714490584e-07), (0, 8.887536750989966e-08), (2, 7.144987534957181e-08), (4, 9.016993374189042e-09)]
# results: [(239, 'na')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpnq8hes8i.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpnq8hes8i.mp4
# top5_label: [(1, 0.9998968839645386), (3, 7.30303509044461e-05), (2, 1.790402711776551e-05), (0, 9.660672731115483e-06), (4, 2.489337475708453e-06)]
# results: [(254, 'na')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp6bklupe3.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp6bklupe3.mp4
# top5_label: [(3, 0.9999877214431763), (1, 6.422074420697754e-06), (4, 3.6783292216568952e-06), (2, 1.4930096767784562e-06), (0, 6.677859119008644e-07)]
# results: [(269, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpfwioc8b6.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpfwioc8b6.mp4
# top5_label: [(3, 0.9997102618217468), (2, 0.00020506461441982538), (4, 4.2797440983122215e-05), (1, 3.619685230660252e-05), (0, 5.599531959887827e-06)]
# results: [(284, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp_kyt72yg.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp_kyt72yg.mp4
# top5_label: [(2, 0.9885984659194946), (3, 0.0112935621291399), (1, 3.905940320692025e-05), (4, 3.570345870684832e-05), (0, 3.3278109185630456e-05)]
# results: [(299, 'si')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp0f_c_dmu.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp0f_c_dmu.mp4
# top5_label: [(2, 0.999993085861206), (3, 3.134181042696582e-06), (0, 2.7947187390964245e-06), (1, 8.000896514204214e-07), (4, 2.405163570529112e-07)]
# results: [(314, 'si')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp27zmdg21.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp27zmdg21.mp4
# top5_label: [(2, 0.9996434450149536), (0, 0.00015378092939499766), (1, 9.095131099456921e-05), (3, 6.721100362483412e-05), (4, 4.4640732085099444e-05)]
# results: [(329, 'si')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp5pa2293j.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp5pa2293j.mp4
# top5_label: [(2, 0.9627326130867004), (1, 0.019693341106176376), (3, 0.009405838325619698), (4, 0.005029104650020599), (0, 0.0031391119118779898)]
# results: [(344, 'si')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpxz579f4p.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpxz579f4p.mp4
# top5_label: [(3, 0.9748674035072327), (2, 0.022173434495925903), (1, 0.0015485358890146017), (4, 0.0009383047581650317), (0, 0.00047236299724318087)]
# results: [(359, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpcattigv2.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpcattigv2.mp4
# top5_label: [(3, 0.9998944997787476), (1, 4.164540223428048e-05), (2, 2.230919199064374e-05), (0, 2.1403837308753282e-05), (4, 2.0134521037107334e-05)]
# results: [(374, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmphpin0c40.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmphpin0c40.mp4
# top5_label: [(3, 0.9397001266479492), (4, 0.0564531646668911), (0, 0.0014572336804121733), (1, 0.0012060252483934164), (2, 0.0011834754841402173)]
# results: [(389, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpb9_hrqlg.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpb9_hrqlg.mp4
# top5_label: [(4, 0.9984192848205566), (3, 0.001332392799668014), (0, 0.00019049248658120632), (1, 4.01520956074819e-05), (2, 1.777956640580669e-05)]
# results: [(404, 'zhuan')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpw7crg57o.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpw7crg57o.mp4
# top5_label: [(4, 0.9999881982803345), (0, 7.65090408094693e-06), (3, 3.408944621696719e-06), (1, 6.965591978769226e-07), (2, 1.5769579420066293e-07)]
# results: [(419, 'zhuan')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpddqhqu3n.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpddqhqu3n.mp4
# top5_label: [(4, 0.9999316930770874), (0, 5.0560243835207075e-05), (3, 1.3369561202125624e-05), (1, 3.41254121849488e-06), (2, 9.829363989410922e-07)]
# results: [(434, 'zhuan')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmps07ewkfd.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmps07ewkfd.mp4
# top5_label: [(0, 0.9999698400497437), (3, 1.8529821318225004e-05), (4, 9.176058483717497e-06), (1, 1.5025516404421069e-06), (2, 9.28682197809394e-07)]
# results: [(449, 'en')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpzxmcnyio.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpzxmcnyio.mp4
# top5_label: [(0, 0.8905240297317505), (3, 0.09720446169376373), (2, 0.0072398497723042965), (1, 0.004508563783019781), (4, 0.0005231419345363975)]
# results: [(464, 'en')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpbbhk01o3.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpbbhk01o3.mp4
# top5_label: [(1, 0.9999529123306274), (3, 2.0755111108883284e-05), (2, 1.8787661247188225e-05), (0, 5.355069788492983e-06), (4, 2.165573960155598e-06)]
# results: [(479, 'na')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpty11w9n5.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpty11w9n5.mp4
# top5_label: [(1, 0.9999146461486816), (3, 6.716240022797137e-05), (2, 1.0341428605897818e-05), (0, 4.570301371131791e-06), (4, 3.3103667647083057e-06)]
# results: [(494, 'na')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmprmvnp66r.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmprmvnp66r.mp4
# top5_label: [(3, 0.9995290040969849), (1, 0.00034349175984971225), (4, 0.00010344941256335005), (2, 1.7701753677101806e-05), (0, 6.318385658232728e-06)]
# results: [(509, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmpyrgt6mi4.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmpyrgt6mi4.mp4
# top5_label: [(3, 0.9999164342880249), (4, 3.1503393984166905e-05), (1, 3.0598093871958554e-05), (2, 1.944958967214916e-05), (0, 2.0189868337183725e-06)]
# results: [(524, 'tie')]
# temp_video_path: /root/project/research/action/mmaction2/demo_out/temp/tmp4qgq954_.mp4, temp_video.name: /root/project/research/action/mmaction2/demo_out/temp/tmp4qgq954_.mp4
# top5_label: [(3, 0.8828755021095276), (2, 0.11437922716140747), (1, 0.0017360792262479663), (4, 0.0007933998131193221), (0, 0.00021583250781986862)]
# results: [(539, 'tie')]

# %%
# 合并短视频为一个长视频
from moviepy.editor import VideoFileClip, concatenate_videoclips
clips = [VideoFileClip(temp_path) for temp_path in temp_videos]
# print(f"temp_videos: {temp_videos}")

# %%
final_video = concatenate_videoclips(clips)
final_video.write_videofile(out_filename, codec="libx264")
# Out:
# Moviepy - Building video ../data/xian_video_dataset/output_tsn_video.mp4.
# Moviepy - Writing video ../data/xian_video_dataset/output_tsn_video.mp4
# Moviepy - Done !
# Moviepy - video ready ../data/xian_video_dataset/output_tsn_video.mp4

# %%
# 删除临时文件
for temp_path in temp_videos:
    os.remove(temp_path)

# %%
# 如果你想在Notebook中显示生成的视频，可以使用以下代码
from IPython.display import Video
Video('../data/xian_video_dataset/output_tsn_video.mp4', width=640, height=480)
# Out:
# <video src="../data/xian_video_dataset/output_tsn_video.mp4" controls  width="640"  height="480">
#       Your browser does not support the <code>video</code> element.
#     </video>
